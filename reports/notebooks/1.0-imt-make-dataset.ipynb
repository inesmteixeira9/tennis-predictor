# %%
import click
import sys
sys.path.append('C:/Users/inesm/projectos/tennis-predictor/src/data/')
from make_dataset import load_data
from make_dataset import filter_data
from make_dataset import save_data


input_filepath = 'C:/Users/inesm/projectos/tennis-predictor/data/raw/'
output_filepath = 'C:/Users/inesm/projectos/tennis-predictor/data/interim/'

# %%
dataset = load_data(input_filepath)
dataset
# Out:
#        ATP   Location          Tournament        Date         Series    Court  \
# 0        1   Adelaide  AAPT Championships  31/12/2001  International  Outdoor
# 1        1   Adelaide  AAPT Championships  31/12/2001  International  Outdoor
# 2        1   Adelaide  AAPT Championships  31/12/2001  International  Outdoor
# 3        1   Adelaide  AAPT Championships  31/12/2001  International  Outdoor
# 4        1   Adelaide  AAPT Championships  31/12/2001  International  Outdoor
# ...    ...        ...                 ...         ...            ...      ...
# 36358   18  Sao Paulo         Brasil Open  02/03/2018         ATP250   Indoor
# 36359   18  Sao Paulo         Brasil Open  02/03/2018         ATP250   Indoor
# 36360   18  Sao Paulo         Brasil Open  03/03/2018         ATP250   Indoor
# 36361   18  Sao Paulo         Brasil Open  03/03/2018         ATP250   Indoor
# 36362   18  Sao Paulo         Brasil Open  04/03/2018         ATP250   Indoor
#
# ...

# %%
dataset = filter_data(dataset)
dataset
# Out:
#                  Winner         Loser  WRank  LRank  B365W  B365L Surface  \
# 1371       Johansson T.   Pretzsch A.      7    133  1.100  6.500   Grass
# 1413        Morrison J.       Ilie A.     98    176  1.571  2.250   Grass
# 1409           Lee H.T.    Larsson M.    117    142  2.625  1.444   Grass
# 1407          Godwin N.    Gasquet R.    111    281  1.533  2.375   Grass
# 1384         Youzhny M.    Santoro F.     67     32  1.800  1.909   Grass
# ...                 ...           ...    ...    ...    ...    ...     ...
# 36335  Bautista Agut R.    Pouille L.     23     15  1.660  2.200    Hard
# 36302       Anderson K.  Donaldson J.      8     59  1.300  3.500    Hard
# 36361          Jarry N.   Zeballos H.     73     69  1.900  1.900    Clay
# 36304    Del Potro J.M.   Anderson K.      9      8  1.500  2.620    Hard
# 36362        Fognini F.      Jarry N.     20     73  1.360  3.250    Clay
#
#        match_id
# 1371       1371
# 1413       1413
# 1409       1409
# ...

# %%
save_data(dataset, 'dataset.pkl', output_filepath)
